# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
import warnings
warnings.simplefilter('ignore')

# %%
df_jp_ind = pd.read_csv('./csv_data/雇用_医療福祉_一人当たり賃金_全国_全産業.csv', encoding='shift_jis')
df_jp_category = pd.read_csv('./csv_data/雇用_医療福祉_一人当たり賃金_全国_大分類.csv', encoding='shift_jis')
df_pref_ind = pd.read_csv('./csv_data/雇用_医療福祉_一人当たり賃金_都道府県_全産業.csv', encoding='shift_jis')
df_pref_category = pd.read_csv('./csv_data/雇用_医療福祉_一人当たり賃金_都道府県_大分類.csv', encoding='shift_jis')

# %%
print('====== データサイズ\n', df_jp_ind.shape)
print('====== index\n', df_jp_ind.index)
print('====== カラム名\n', df_jp_ind.columns)
print('====== データ型\n', df_jp_ind.dtypes)
df_jp_ind.head()
# Out:
# ====== データサイズ
#  (130, 5)
# ====== index
#  RangeIndex(start=0, stop=130, step=1)
# ====== カラム名
#  Index(['集計年', '年齢', '所定内給与額（万円）', '年間賞与その他特別給与額（万円）', '一人当たり賃金（万円）'], dtype='object')
# ====== データ型
#  集計年                   int64
# 年齢                   object
# 所定内給与額（万円）          float64
# 年間賞与その他特別給与額（万円）    float64
# 一人当たり賃金（万円）         float64
# dtype: object
#     集計年      年齢  所定内給与額（万円）  年間賞与その他特別給与額（万円）  一人当たり賃金（万円）
# 0  2010     年齢計     29.6219           79.1174     434.5804
# 1  2010    〜19歳     16.7837           13.6030     215.0078
# 2  2010  20〜24歳     19.4890           35.6139     269.4816
# 3  2010  25〜29歳     22.8221           55.3967     329.2620
# 4  2010  30〜34歳     26.3490           67.9498     384.1379

# %%
print('====== データサイズ\n', df_jp_category.shape)
print('====== index\n', df_jp_category.index)
print('====== カラム名\n', df_jp_category.columns)
print('====== データ型\n', df_jp_category.dtypes)
df_jp_category.head()
# Out:
# ====== データサイズ
#  (2080, 7)
# ====== index
#  RangeIndex(start=0, stop=2080, step=1)
# ====== カラム名
#  Index(['集計年', '産業大分類コード', '産業大分類名', '年齢', '所定内給与額（万円）', '年間賞与その他特別給与額（万円）',
#        '一人当たり賃金（万円）'],
#       dtype='object')
# ====== データ型
#  集計年                   int64
# 産業大分類コード             object
# 産業大分類名               object
# 年齢                   object
# 所定内給与額（万円）          float64
# 年間賞与その他特別給与額（万円）    float64
# 一人当たり賃金（万円）         float64
# dtype: object
#     集計年 産業大分類コード        産業大分類名      年齢  所定内給与額（万円）  年間賞与その他特別給与額（万円）  \
# 0  2010        C  鉱業，採石業，砂利採取業     年齢計     31.2283           93.9023
# 1  2010        C  鉱業，採石業，砂利採取業    〜19歳     18.3400           28.2117
# 2  2010        C  鉱業，採石業，砂利採取業  20〜24歳     20.5200           67.4473
# 3  2010        C  鉱業，採石業，砂利採取業  25〜29歳     25.0535           76.8142
# 4  2010        C  鉱業，採石業，砂利採取業  30〜34歳     27.8412           72.1694
#
#    一人当たり賃金（万円）
# 0     468.6416
# 1     248.2917
# 2     313.6873
# 3     377.4560
# 4     406.2639

# %%
print('====== データサイズ\n', df_pref_ind.shape)
print('====== index\n', df_pref_ind.index)
print('====== カラム名\n', df_pref_ind.columns)
print('====== データ型\n', df_pref_ind.dtypes)
df_pref_ind.head()
# Out:
# ====== データサイズ
#  (6110, 7)
# ====== index
#  RangeIndex(start=0, stop=6110, step=1)
# ====== カラム名
#  Index(['集計年', '都道府県コード', '都道府県名', '年齢', '所定内給与額（万円）', '年間賞与その他特別給与額（万円）',
#        '一人当たり賃金（万円）'],
#       dtype='object')
# ====== データ型
#  集計年                   int64
# 都道府県コード               int64
# 都道府県名                object
# 年齢                   object
# 所定内給与額（万円）          float64
# 年間賞与その他特別給与額（万円）    float64
# 一人当たり賃金（万円）         float64
# dtype: object
#     集計年  都道府県コード 都道府県名      年齢  所定内給与額（万円）  年間賞与その他特別給与額（万円）  一人当たり賃金（万円）
# 0  2010        1   北海道     年齢計       26.23             67.15       381.91
# 1  2010        1   北海道    〜19歳       15.29             14.41       197.89
# 2  2010        1   北海道  20〜24歳       18.04             30.16       246.64
# 3  2010        1   北海道  25〜29歳       20.93             48.06       299.22
# 4  2010        1   北海道  30〜34歳       24.08             57.10       346.06

# %%
print('====== データサイズ\n', df_pref_category.shape)
print('====== index\n', df_pref_category.index)
print('====== カラム名\n', df_pref_category.columns)
print('====== データ型\n', df_pref_category.dtypes)
df_pref_category.head()
# Out:
# ====== データサイズ
#  (97760, 9)
# ====== index
#  RangeIndex(start=0, stop=97760, step=1)
# ====== カラム名
#  Index(['集計年', '都道府県コード', '都道府県名', '産業大分類コード', '産業大分類名', '年齢', '所定内給与額（万円）',
#        '年間賞与その他特別給与額（万円）', '一人当たり賃金（万円）'],
#       dtype='object')
# ====== データ型
#  集計年                  int64
# 都道府県コード              int64
# 都道府県名               object
# 産業大分類コード            object
# 産業大分類名              object
# 年齢                  object
# 所定内給与額（万円）          object
# 年間賞与その他特別給与額（万円）    object
# 一人当たり賃金（万円）         object
# dtype: object
#     集計年  都道府県コード 都道府県名 産業大分類コード        産業大分類名      年齢 所定内給与額（万円）  \
# 0  2010        1   北海道        C  鉱業，採石業，砂利採取業     年齢計      28.85
# 1  2010        1   北海道        C  鉱業，採石業，砂利採取業    〜19歳      18.84
# 2  2010        1   北海道        C  鉱業，採石業，砂利採取業  20〜24歳      21.13
# 3  2010        1   北海道        C  鉱業，採石業，砂利採取業  25〜29歳      25.25
# 4  2010        1   北海道        C  鉱業，採石業，砂利採取業  30〜34歳      24.54
#
#   年間賞与その他特別給与額（万円） 一人当たり賃金（万円）
# 0            74.95      421.15
# 1            19.88      245.96
# 2            89.56      343.12
# 3            83.94      386.94
# 4            66.53      361.01

# %%
df_pref_category[1001:1006]
# Out:
#        集計年  都道府県コード 都道府県名 産業大分類コード 産業大分類名      年齢 所定内給与額（万円） 年間賞与その他特別給与額（万円）  \
# 1001  2010        5   秋田県        P  医療，福祉     年齢計      23.06            64.68
# 1002  2010        5   秋田県        P  医療，福祉    〜19歳      13.91              3.8
# 1003  2010        5   秋田県        P  医療，福祉  20〜24歳      17.27            32.09
# 1004  2010        5   秋田県        P  医療，福祉  25〜29歳      20.22            53.59
# 1005  2010        5   秋田県        P  医療，福祉  30〜34歳      21.04            61.73
#
#      一人当たり賃金（万円）
# 1001       341.4
# 1002      170.72
# 1003      239.33
# 1004      296.23
# 1005      314.21

# %%
df_pref_category.loc[15000]
# Out:
# 集計年                   2011
# 都道府県コード                 26
# 都道府県名                  京都府
# 産業大分類コード                 D
# 産業大分類名                 建設業
# 年齢                  65〜69歳
# 所定内給与額（万円）           27.56
# 年間賞与その他特別給与額（万円）      50.5
# 一人当たり賃金（万円）         381.22
# Name: 15000, dtype: object

# %%
df_pref_category.tail()
# Out:
#         集計年  都道府県コード 都道府県名 産業大分類コード             産業大分類名      年齢 所定内給与額（万円）  \
# 97755  2019       47   沖縄県        R  サービス業（他に分類されないもの）  50〜54歳      25.04
# 97756  2019       47   沖縄県        R  サービス業（他に分類されないもの）  55〜59歳      23.12
# 97757  2019       47   沖縄県        R  サービス業（他に分類されないもの）  60〜64歳      21.65
# 97758  2019       47   沖縄県        R  サービス業（他に分類されないもの）  65〜69歳      16.95
# 97759  2019       47   沖縄県        R  サービス業（他に分類されないもの）    70歳〜      15.12
#
#       年間賞与その他特別給与額（万円） 一人当たり賃金（万円）
# 97755            48.17      348.65
# 97756            35.72      313.16
# 97757               21       280.8
# 97758            12.73      216.13
# 97759             2.34      183.78

# %%
df_pref_category['産業大分類名'].unique()
# Out:
# array(['鉱業，採石業，砂利採取業', '建設業', '製造業', '電気・ガス・熱供給・水道業', '情報通信業', '運輸業，郵便業',
#        '卸売業，小売業', '金融業，保険業', '不動産業，物品賃貸業', '学術研究，専門・技術サービス業',
#        '宿泊業，飲食サービス業', '生活関連サービス業，娯楽業', '教育，学習支援業', '医療，福祉', '複合サービス事業',
#        'サービス業（他に分類されないもの）'], dtype=object)

# %%
df_pref_category['産業大分類名'].nunique()
# Out:
# 16

# %%
df_pref_category['年齢'].unique()
# Out:
# array(['年齢計', '〜19歳', '20〜24歳', '25〜29歳', '30〜34歳', '35〜39歳', '40〜44歳',
#        '45〜49歳', '50〜54歳', '55〜59歳', '60〜64歳', '65〜69歳', '70歳〜'],
#       dtype=object)

# %%
df_pref_category['年齢'].nunique()
# Out:
# 13

# %%
df_pref_category['年齢'].unique()
# Out:
# array(['年齢計', '〜19歳', '20〜24歳', '25〜29歳', '30〜34歳', '35〜39歳', '40〜44歳',
#        '45〜49歳', '50〜54歳', '55〜59歳', '60〜64歳', '65〜69歳', '70歳〜'],
#       dtype=object)

# %%
df_jp_ind.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 125    False
# 126    False
# 127    False
# 128    False
# 129    False
# Length: 130, dtype: bool

# %%
df_jp_ind.duplicated().any()
# Out:
# False

# %%
print(df_jp_category.duplicated().any())
print(df_pref_ind.duplicated().any())
print(df_pref_category.duplicated().any())
# Out:
# False
# False
# False

# %%
df_jp_ind.isnull().sum()
# Out:
# 集計年                 0
# 年齢                  0
# 所定内給与額（万円）          0
# 年間賞与その他特別給与額（万円）    0
# 一人当たり賃金（万円）         0
# dtype: int64

# %%
df_jp_ind.isnull().sum(axis=1)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 125    0
# 126    0
# 127    0
# 128    0
# 129    0
# Length: 130, dtype: int64

# %%
df_jp_category.isnull().sum()
# Out:
# 集計年                 0
# 産業大分類コード            0
# 産業大分類名              0
# 年齢                  0
# 所定内給与額（万円）          0
# 年間賞与その他特別給与額（万円）    0
# 一人当たり賃金（万円）         0
# dtype: int64

# %%
df_pref_ind.isnull().sum()
# Out:
# 集計年                 0
# 都道府県コード             0
# 都道府県名               0
# 年齢                  0
# 所定内給与額（万円）          0
# 年間賞与その他特別給与額（万円）    0
# 一人当たり賃金（万円）         0
# dtype: int64

# %%
df_pref_category.isnull().sum()
# Out:
# 集計年                 0
# 都道府県コード             0
# 都道府県名               0
# 産業大分類コード            0
# 産業大分類名              0
# 年齢                  0
# 所定内給与額（万円）          0
# 年間賞与その他特別給与額（万円）    0
# 一人当たり賃金（万円）         0
# dtype: int64

# %%
print('====== データ型\n', df_pref_category.dtypes)
# Out:
# ====== データ型
#  集計年                  int64
# 都道府県コード              int64
# 都道府県名               object
# 産業大分類コード            object
# 産業大分類名              object
# 年齢                  object
# 所定内給与額（万円）          object
# 年間賞与その他特別給与額（万円）    object
# 一人当たり賃金（万円）         object
# dtype: object

# %%
print('====== データ型\n', df_pref_ind.dtypes)
# Out:
# ====== データ型
#  集計年                   int64
# 都道府県コード               int64
# 都道府県名                object
# 年齢                   object
# 所定内給与額（万円）          float64
# 年間賞与その他特別給与額（万円）    float64
# 一人当たり賃金（万円）         float64
# dtype: object

# %%
print('====== データ型\n', df_jp_category.dtypes)
# Out:
# ====== データ型
#  集計年                   int64
# 産業大分類コード             object
# 産業大分類名               object
# 年齢                   object
# 所定内給与額（万円）          float64
# 年間賞与その他特別給与額（万円）    float64
# 一人当たり賃金（万円）         float64
# dtype: object

# %%
print('====== データ型\n', df_jp_ind.dtypes)
# Out:
# ====== データ型
#  集計年                   int64
# 年齢                   object
# 所定内給与額（万円）          float64
# 年間賞与その他特別給与額（万円）    float64
# 一人当たり賃金（万円）         float64
# dtype: object

# %%
df_pref_category['所定内給与額（万円）'] = df_pref_category['所定内給与額（万円）'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [128], in <cell line: 1>()
# ----> 1 df_pref_category['所定内給与額（万円）'] = df_pref_category['所定内給与額（万円）'].astype(float)
#
# File ~/Applications/anaconda/anaconda3/envs/pd_streamlit/lib/python3.8/site-packages/pandas/core/generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~/Applications/anaconda/anaconda3/envs/pd_streamlit/lib/python3.8/site-packages/pandas/core/internals/managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
#     418 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~/Applications/anaconda/anaconda3/envs/pd_streamlit/lib/python3.8/site-packages/pandas/core/internals/managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File ~/Applications/anaconda/anaconda3/envs/pd_streamlit/lib/python3.8/site-packages/pandas/core/internals/blocks.py:580, in Block.astype(self, dtype, copy, errors)
#     562 """
#     563 Coerce to the new dtype.
#     564
#    (...)
#     576 Block
#     577 """
#     578 values = self.values
# --> 580 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     582 new_values = maybe_coerce_values(new_values)
#     583 newb = self.make_block(new_values)
#
# File ~/Applications/anaconda/anaconda3/envs/pd_streamlit/lib/python3.8/site-packages/pandas/core/dtypes/cast.py:1292, in astype_array_safe(values, dtype, copy, errors)
#    1289     dtype = dtype.numpy_dtype
#    1291 try:
# -> 1292     new_values = astype_array(values, dtype, copy=copy)
#    1293 except (ValueError, TypeError):
#    1294     # e.g. astype_nansafe can fail on object-dtype of strings
#    1295     #  trying to convert to float
#    1296     if errors == "ignore":
#
# File ~/Applications/anaconda/anaconda3/envs/pd_streamlit/lib/python3.8/site-packages/pandas/core/dtypes/cast.py:1237, in astype_array(values, dtype, copy)
#    1234     values = values.astype(dtype, copy=copy)
#    1236 else:
# -> 1237     values = astype_nansafe(values, dtype, copy=copy)
#    1239 # in pandas we don't store numpy str dtypes, so convert to object
#    1240 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/Applications/anaconda/anaconda3/envs/pd_streamlit/lib/python3.8/site-packages/pandas/core/dtypes/cast.py:1181, in astype_nansafe(arr, dtype, copy, skipna)
#    1177     raise ValueError(msg)
#    1179 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#    1180     # Explicit copy, or required since NumPy can't view from / to object.
# -> 1181     return arr.astype(dtype, copy=True)
#    1183 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '-'

# %%
df_pref_category[df_pref_category['所定内給与額（万円）'] == '-']
# Out:
#         集計年  都道府県コード 都道府県名 産業大分類コード           産業大分類名      年齢 所定内給与額（万円）  \
# 51     2010        1   北海道        F    電気・ガス・熱供給・水道業    70歳〜          -
# 129    2010        1   北海道        L  学術研究，専門・技術サービス業    70歳〜          -
# 157    2010        1   北海道        O         教育，学習支援業    〜19歳          -
# 194    2010        1   北海道        Q         複合サービス事業    70歳〜          -
# 219    2010        2   青森県        C     鉱業，採石業，砂利採取業  65〜69歳          -
# ...     ...      ...   ...      ...              ...     ...        ...
# 97603  2019       47   沖縄県        F    電気・ガス・熱供給・水道業    70歳〜          -
# 97655  2019       47   沖縄県        J          金融業，保険業    70歳〜          -
# 97670  2019       47   沖縄県        L  学術研究，専門・技術サービス業    〜19歳          -
# 97735  2019       47   沖縄県        Q         複合サービス事業    〜19歳          -
# 97746  2019       47   沖縄県        Q         複合サービス事業    70歳〜          -
#
#       年間賞与その他特別給与額（万円） 一人当たり賃金（万円）
# 51                   -           -
# 129                  -           -
# 157                  -           -
# 194                  -           -
# 219                  -           -
# ...                ...         ...
# 97603                -           -
# 97655                -           -
# 97670                -           -
# 97735                -           -
# 97746                -           -
#
# [3526 rows x 9 columns]

# %%
df_pref_category['所定内給与額（万円）'] == '-'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 97755    False
# 97756    False
# 97757    False
# 97758    False
# 97759    False
# Name: 所定内給与額（万円）, Length: 97760, dtype: bool

# %%
df_pref_category[df_pref_category['所定内給与額（万円）'].str.contains('-')]
# Out:
#         集計年  都道府県コード 都道府県名 産業大分類コード           産業大分類名      年齢 所定内給与額（万円）  \
# 51     2010        1   北海道        F    電気・ガス・熱供給・水道業    70歳〜          -
# 129    2010        1   北海道        L  学術研究，専門・技術サービス業    70歳〜          -
# 157    2010        1   北海道        O         教育，学習支援業    〜19歳          -
# 194    2010        1   北海道        Q         複合サービス事業    70歳〜          -
# 219    2010        2   青森県        C     鉱業，採石業，砂利採取業  65〜69歳          -
# ...     ...      ...   ...      ...              ...     ...        ...
# 97603  2019       47   沖縄県        F    電気・ガス・熱供給・水道業    70歳〜          -
# 97655  2019       47   沖縄県        J          金融業，保険業    70歳〜          -
# 97670  2019       47   沖縄県        L  学術研究，専門・技術サービス業    〜19歳          -
# 97735  2019       47   沖縄県        Q         複合サービス事業    〜19歳          -
# 97746  2019       47   沖縄県        Q         複合サービス事業    70歳〜          -
#
#       年間賞与その他特別給与額（万円） 一人当たり賃金（万円）
# 51                   -           -
# 129                  -           -
# 157                  -           -
# 194                  -           -
# 219                  -           -
# ...                ...         ...
# 97603                -           -
# 97655                -           -
# 97670                -           -
# 97735                -           -
# 97746                -           -
#
# [3526 rows x 9 columns]

# %%
temp_df = df_pref_category[df_pref_category['所定内給与額（万円）'] == '-']
temp_df.head()
# Out:
#       集計年  都道府県コード 都道府県名 産業大分類コード           産業大分類名      年齢 所定内給与額（万円）  \
# 51   2010        1   北海道        F    電気・ガス・熱供給・水道業    70歳〜          -
# 129  2010        1   北海道        L  学術研究，専門・技術サービス業    70歳〜          -
# 157  2010        1   北海道        O         教育，学習支援業    〜19歳          -
# 194  2010        1   北海道        Q         複合サービス事業    70歳〜          -
# 219  2010        2   青森県        C     鉱業，採石業，砂利採取業  65〜69歳          -
#
#     年間賞与その他特別給与額（万円） 一人当たり賃金（万円）
# 51                 -           -
# 129                -           -
# 157                -           -
# 194                -           -
# 219                -           -

# %%
temp_df['年齢'].unique()
# Out:
# array(['70歳〜', '〜19歳', '65〜69歳', '20〜24歳', '30〜34歳', '25〜29歳', '60〜64歳',
#        '35〜39歳', '50〜54歳', '45〜49歳', '40〜44歳', '年齢計', '55〜59歳'],
#       dtype=object)

# %%
temp_df['年齢'].value_counts()
# Out:
# 70歳〜      1701
# 〜19歳       950
# 65〜69歳     433
# 20〜24歳     171
# 25〜29歳      89
# 30〜34歳      43
# 35〜39歳      33
# 60〜64歳      25
# 40〜44歳      22
# 55〜59歳      17
# 50〜54歳      16
# 45〜49歳      15
# 年齢計         11
# Name: 年齢, dtype: int64

# %%
temp_df['都道府県名'].value_counts()
# Out:
# 奈良県     166
# 滋賀県     135
# 鳥取県     134
# 徳島県     113
# 愛媛県     106
# 沖縄県     100
# 香川県     100
# 和歌山県     95
# 群馬県      91
# 高知県      89
# 大阪府      88
# 石川県      87
# 山梨県      86
# 島根県      85
# 山形県      84
# 宮城県      82
# 新潟県      82
# 茨城県      82
# 広島県      81
# 佐賀県      81
# 福井県      78
# 長野県      76
# 宮崎県      75
# 京都府      74
# 福島県      73
# 兵庫県      72
# 秋田県      69
# 富山県      67
# 山口県      67
# 熊本県      65
# 岡山県      65
# 岐阜県      63
# 青森県      62
# 岩手県      62
# 大分県      59
# 鹿児島県     58
# 静岡県      58
# 栃木県      58
# 長崎県      56
# 三重県      54
# 愛知県      47
# 神奈川県     46
# 埼玉県      43
# 福岡県      34
# 千葉県      33
# 北海道      32
# 東京都      13
# Name: 都道府県名, dtype: int64

# %%
temp_df['産業大分類名'].value_counts()
# Out:
# 鉱業，採石業，砂利採取業         1121
# 情報通信業                 551
# 電気・ガス・熱供給・水道業         546
# 複合サービス事業              412
# 教育，学習支援業              227
# 学術研究，専門・技術サービス業       200
# 不動産業，物品賃貸業            144
# 金融業，保険業               131
# 生活関連サービス業，娯楽業          61
# 医療，福祉                  53
# 建設業                    40
# 運輸業，郵便業                14
# 卸売業，小売業                12
# 宿泊業，飲食サービス業            10
# サービス業（他に分類されないもの）       4
# Name: 産業大分類名, dtype: int64

# %%
df_pref_category['所定内給与額（万円）'] = df_pref_category['所定内給与額（万円）'].replace('-', np.nan)
df_pref_category['年間賞与その他特別給与額（万円）'] = df_pref_category['年間賞与その他特別給与額（万円）'].replace('-', np.nan)
df_pref_category['一人当たり賃金（万円）'] = df_pref_category['一人当たり賃金（万円）'].replace('-', np.nan)

# %%
df_pref_category.isnull().sum()
# Out:
# 集計年                    0
# 都道府県コード                0
# 都道府県名                  0
# 産業大分類コード               0
# 産業大分類名                 0
# 年齢                     0
# 所定内給与額（万円）          3526
# 年間賞与その他特別給与額（万円）    3526
# 一人当たり賃金（万円）         3526
# dtype: int64

# %%
df_pref_category.dropna(subset=['所定内給与額（万円）'], axis=0, inplace=True)

# %%
print(df_pref_category.shape)
# Out:
# (94234, 9)

# %%
df_pref_category.isnull().sum()
# Out:
# 集計年                 0
# 都道府県コード             0
# 都道府県名               0
# 産業大分類コード            0
# 産業大分類名              0
# 年齢                  0
# 所定内給与額（万円）          0
# 年間賞与その他特別給与額（万円）    0
# 一人当たり賃金（万円）         0
# dtype: int64

# %%
df_pref_category = df_pref_category.astype({'所定内給与額（万円）': float, '年間賞与その他特別給与額（万円）': float, '一人当たり賃金（万円）': float})

# %%
print('======= データ型\n', df_pref_category.dtypes)
# Out:
# ======= データ型
#  集計年                   int64
# 都道府県コード               int64
# 都道府県名                object
# 産業大分類コード             object
# 産業大分類名               object
# 年齢                   object
# 所定内給与額（万円）          float64
# 年間賞与その他特別給与額（万円）    float64
# 一人当たり賃金（万円）         float64
# dtype: object

# %%
df_jp_category[df_jp_category['一人当たり賃金（万円）'] > 400]
# Out:
#        集計年 産業大分類コード             産業大分類名      年齢  所定内給与額（万円）  年間賞与その他特別給与額（万円）  \
# 0     2010        C       鉱業，採石業，砂利採取業     年齢計     31.2283           93.9023
# 4     2010        C       鉱業，採石業，砂利採取業  30〜34歳     27.8412           72.1694
# 5     2010        C       鉱業，採石業，砂利採取業  35〜39歳     30.6428           88.4950
# 6     2010        C       鉱業，採石業，砂利採取業  40〜44歳     32.3186          101.8686
# 7     2010        C       鉱業，採石業，砂利採取業  45〜49歳     35.3451          122.9471
# ...    ...      ...                ...     ...         ...               ...
# 2063  2019        Q           複合サービス事業  55〜59歳     37.1388          131.3999
# 2073  2019        R  サービス業（他に分類されないもの）  40〜44歳     28.3622           68.4621
# 2074  2019        R  サービス業（他に分類されないもの）  45〜49歳     29.3146           70.3673
# 2075  2019        R  サービス業（他に分類されないもの）  50〜54歳     29.3721           68.5499
# 2076  2019        R  サービス業（他に分類されないもの）  55〜59歳     29.4049           71.2225
#
#       一人当たり賃金（万円）
# 0        468.6416
# 4        406.2639
# 5        456.2090
# 6        489.6920
# 7        547.0881
# ...           ...
# 2063     577.0656
# 2073     408.8090
# 2074     422.1430
# 2075     421.0152
# 2076     424.0817
#
# [1069 rows x 7 columns]

# %%
df_pref_category[(df_pref_category["都道府県名"] == "東京都") & (df_pref_category["一人当たり賃金（万円）"] > 900)]
# Out:
#         集計年  都道府県コード 都道府県名 産業大分類コード           産業大分類名      年齢  所定内給与額（万円）  \
# 2503   2010       13   東京都        C     鉱業，採石業，砂利採取業  45〜49歳       58.88
# 2504   2010       13   東京都        C     鉱業，採石業，砂利採取業  50〜54歳       66.59
# 2505   2010       13   東京都        C     鉱業，採石業，砂利採取業  55〜59歳       68.96
# 2556   2010       13   東京都        G            情報通信業  50〜54歳       64.22
# 2557   2010       13   東京都        G            情報通信業  55〜59歳       60.30
# ...     ...      ...   ...      ...              ...     ...         ...
# 90606  2019       13   東京都        L  学術研究，専門・技術サービス業  55〜59歳       55.29
# 90644  2019       13   東京都        O         教育，学習支援業  50〜54歳       58.58
# 90645  2019       13   東京都        O         教育，学習支援業  55〜59歳       63.57
# 90646  2019       13   東京都        O         教育，学習支援業  60〜64歳       62.22
# 90647  2019       13   東京都        O         教育，学習支援業  65〜69歳       63.25
#
#        年間賞与その他特別給与額（万円）  一人当たり賃金（万円）
# 2503             341.39      1047.95
# 2504             415.81      1214.89
# 2505             432.67      1260.19
# 2556             207.55       978.19
# 2557             182.65       906.25
# ...                 ...          ...
# 90606            242.54       906.02
# 90644            271.15       974.11
# 90645            301.49      1064.33
# 90646            306.26      1052.90
# 90647            262.77      1021.77
#
# [106 rows x 9 columns]

# %%
df_pref_category[(df_pref_category["都道府県名"] == "東京都") & (df_pref_category["一人当たり賃金（万円）"] > 900)]
# Out:
#         集計年  都道府県コード 都道府県名 産業大分類コード           産業大分類名      年齢  所定内給与額（万円）  \
# 2503   2010       13   東京都        C     鉱業，採石業，砂利採取業  45〜49歳       58.88
# 2504   2010       13   東京都        C     鉱業，採石業，砂利採取業  50〜54歳       66.59
# 2505   2010       13   東京都        C     鉱業，採石業，砂利採取業  55〜59歳       68.96
# 2556   2010       13   東京都        G            情報通信業  50〜54歳       64.22
# 2557   2010       13   東京都        G            情報通信業  55〜59歳       60.30
# ...     ...      ...   ...      ...              ...     ...         ...
# 90606  2019       13   東京都        L  学術研究，専門・技術サービス業  55〜59歳       55.29
# 90644  2019       13   東京都        O         教育，学習支援業  50〜54歳       58.58
# 90645  2019       13   東京都        O         教育，学習支援業  55〜59歳       63.57
# 90646  2019       13   東京都        O         教育，学習支援業  60〜64歳       62.22
# 90647  2019       13   東京都        O         教育，学習支援業  65〜69歳       63.25
#
#        年間賞与その他特別給与額（万円）  一人当たり賃金（万円）
# 2503             341.39      1047.95
# 2504             415.81      1214.89
# 2505             432.67      1260.19
# 2556             207.55       978.19
# 2557             182.65       906.25
# ...                 ...          ...
# 90606            242.54       906.02
# 90644            271.15       974.11
# 90645            301.49      1064.33
# 90646            306.26      1052.90
# 90647            262.77      1021.77
#
# [106 rows x 9 columns]

# %%
df_jp_ind.head()
# Out:
#     集計年      年齢  所定内給与額（万円）  年間賞与その他特別給与額（万円）  一人当たり賃金（万円）
# 0  2010     年齢計     29.6219           79.1174     434.5804
# 1  2010    〜19歳     16.7837           13.6030     215.0078
# 2  2010  20〜24歳     19.4890           35.6139     269.4816
# 3  2010  25〜29歳     22.8221           55.3967     329.2620
# 4  2010  30〜34歳     26.3490           67.9498     384.1379

# %%
df_jp_ind[(df_jp_ind["年齢"] == "年齢計")]
# Out:
#       集計年   年齢  所定内給与額（万円）  年間賞与その他特別給与額（万円）  一人当たり賃金（万円）
# 0    2010  年齢計     29.6219           79.1174     434.5804
# 13   2011  年齢計     29.6784           82.3747     438.5151
# 26   2012  年齢計     29.7757           81.9302     439.2385
# 39   2013  年齢計     29.5735           80.1316     435.0136
# 52   2014  年齢計     29.9630           84.1634     443.7198
# 65   2015  年齢計     30.4022           89.2692     454.0960
# 78   2016  年齢計     30.3988           89.4192     454.2043
# 91   2017  年齢計     30.4291           90.5953     455.7445
# 104  2018  年齢計     30.6196           93.1651     460.6006
# 117  2019  年齢計     30.7692           95.0934     464.3237

# %%
df_diff = df_jp_ind[(df_jp_ind["年齢"] == "年齢計")]

# %%
print(df_diff)
# Out:
#       集計年   年齢  所定内給与額（万円）  年間賞与その他特別給与額（万円）  一人当たり賃金（万円）
# 0    2010  年齢計     29.6219           79.1174     434.5804
# 13   2011  年齢計     29.6784           82.3747     438.5151
# 26   2012  年齢計     29.7757           81.9302     439.2385
# 39   2013  年齢計     29.5735           80.1316     435.0136
# 52   2014  年齢計     29.9630           84.1634     443.7198
# 65   2015  年齢計     30.4022           89.2692     454.0960
# 78   2016  年齢計     30.3988           89.4192     454.2043
# 91   2017  年齢計     30.4291           90.5953     455.7445
# 104  2018  年齢計     30.6196           93.1651     460.6006
# 117  2019  年齢計     30.7692           95.0934     464.3237

# %%
df_diff['一人当たり賃金の差分（万円）'] = df_diff['一人当たり賃金（万円）'].diff()
df_diff
# Out:
#       集計年   年齢  所定内給与額（万円）  年間賞与その他特別給与額（万円）  一人当たり賃金（万円）  一人当たり賃金の差分（万円）
# 0    2010  年齢計     29.6219           79.1174     434.5804             NaN
# 13   2011  年齢計     29.6784           82.3747     438.5151          3.9347
# 26   2012  年齢計     29.7757           81.9302     439.2385          0.7234
# 39   2013  年齢計     29.5735           80.1316     435.0136         -4.2249
# 52   2014  年齢計     29.9630           84.1634     443.7198          8.7062
# 65   2015  年齢計     30.4022           89.2692     454.0960         10.3762
# 78   2016  年齢計     30.3988           89.4192     454.2043          0.1083
# 91   2017  年齢計     30.4291           90.5953     455.7445          1.5402
# 104  2018  年齢計     30.6196           93.1651     460.6006          4.8561
# 117  2019  年齢計     30.7692           95.0934     464.3237          3.7231

# %%
df_jp_ind.groupby('年齢')['一人当たり賃金（万円）'].mean()
# Out:
# 年齢
# 20〜24歳    277.81414
# 25〜29歳    342.92576
# 30〜34歳    396.07938
# 35〜39歳    446.59957
# 40〜44歳    496.88205
# 45〜49歳    543.15976
# 50〜54歳    566.64412
# 55〜59歳    541.54213
# 60〜64歳    381.00704
# 65〜69歳    334.32060
# 70歳〜      329.82376
# 〜19歳      217.73694
# 年齢計       448.00365
# Name: 一人当たり賃金（万円）, dtype: float64

# %%
df_jp_ind.groupby(['年齢'])[['所定内給与額（万円）', '年間賞与その他特別給与額（万円）', '一人当たり賃金（万円）']].mean()
# Out:
#         所定内給与額（万円）  年間賞与その他特別給与額（万円）  一人当たり賃金（万円）
# 年齢
# 20〜24歳    20.13079          36.24459    277.81414
# 25〜29歳    23.39559          62.17854    342.92576
# 30〜34歳    26.73669          75.23903    396.07938
# 35〜39歳    29.92850          87.45758    446.59957
# 40〜44歳    32.96131         101.34630    496.88205
# 45〜49歳    35.72125         114.50490    543.15976
# 50〜54歳    37.17460         120.54884    566.64412
# 55〜59歳    35.89715         110.77626    541.54213
# 60〜64歳    26.93428          57.79566    381.00704
# 65〜69歳    24.91573          35.33183    334.32060
# 70歳〜      25.14783          28.04974    329.82376
# 〜19歳      17.12546          12.23127    217.73694
# 年齢計       30.12314          86.52595    448.00365

# %%
df_jp_category.head()
# Out:
#     集計年 産業大分類コード        産業大分類名      年齢  所定内給与額（万円）  年間賞与その他特別給与額（万円）  \
# 0  2010        C  鉱業，採石業，砂利採取業     年齢計     31.2283           93.9023
# 1  2010        C  鉱業，採石業，砂利採取業    〜19歳     18.3400           28.2117
# 2  2010        C  鉱業，採石業，砂利採取業  20〜24歳     20.5200           67.4473
# 3  2010        C  鉱業，採石業，砂利採取業  25〜29歳     25.0535           76.8142
# 4  2010        C  鉱業，採石業，砂利採取業  30〜34歳     27.8412           72.1694
#
#    一人当たり賃金（万円）
# 0     468.6416
# 1     248.2917
# 2     313.6873
# 3     377.4560
# 4     406.2639

# %%
df_temp = df_jp_category[df_jp_category['年齢'] == '年齢計']

# %%
df_temp
# Out:
#        集計年 産業大分類コード             産業大分類名   年齢  所定内給与額（万円）  年間賞与その他特別給与額（万円）  \
# 0     2010        C       鉱業，採石業，砂利採取業  年齢計     31.2283           93.9023
# 13    2010        D                建設業  年齢計     30.8300           61.5848
# 26    2010        E                製造業  年齢計     29.2249           86.0234
# 39    2010        F      電気・ガス・熱供給・水道業  年齢計     39.9261          160.3722
# 52    2010        G              情報通信業  年齢計     36.3342          110.7938
# ...    ...      ...                ...  ...         ...               ...
# 2015  2019        N      生活関連サービス業，娯楽業  年齢計     26.3556           46.3902
# 2028  2019        O           教育，学習支援業  年齢計     38.7862          141.0095
# 2041  2019        P              医療，福祉  年齢計     28.4848           69.9111
# 2054  2019        Q           複合サービス事業  年齢計     29.9917          100.0556
# 2067  2019        R  サービス業（他に分類されないもの）  年齢計     26.2561           55.1508
#
#       一人当たり賃金（万円）
# 0        468.6416
# 13       431.5451
# 26       436.7223
# 39       639.4850
# 52       546.8040
# ...           ...
# 2015     362.6570
# 2028     606.4442
# 2041     411.7284
# 2054     459.9554
# 2067     370.2243
#
# [160 rows x 7 columns]

# %%
df_temp.groupby('産業大分類名')[['所定内給与額（万円）', '年間賞与その他特別給与額（万円）', '一人当たり賃金（万円）']].mean()
# Out:
#                    所定内給与額（万円）  年間賞与その他特別給与額（万円）  一人当たり賃金（万円）
# 産業大分類名
# サービス業（他に分類されないもの）    25.43604          50.27257    355.50502
# 不動産業，物品賃貸業           32.01639          94.96252    479.15911
# 医療，福祉                27.72835          67.83543    400.57547
# 卸売業，小売業              30.27402          86.92866    450.21691
# 学術研究，専門・技術サービス業      37.54520         125.87415    576.41645
# 宿泊業，飲食サービス業          24.01092          31.60651    319.73752
# 建設業                  32.30151          84.54445    472.16253
# 情報通信業                37.64942         121.61589    573.40888
# 教育，学習支援業             38.35989         136.27081    596.58965
# 生活関連サービス業，娯楽業        25.59193          41.76978    348.87293
# 製造業                  29.29134          96.82227    448.31834
# 複合サービス事業             29.12677          94.45143    443.97265
# 運輸業，郵便業              26.87831          58.00221    380.54166
# 金融業，保険業              37.08927         141.87859    586.94974
# 鉱業，採石業，砂利採取業         31.63019         104.37443    483.93678
# 電気・ガス・熱供給・水道業        40.75261         123.53839    612.56956

# %%
df_pref_ind.head()
# Out:
#     集計年  都道府県コード 都道府県名      年齢  所定内給与額（万円）  年間賞与その他特別給与額（万円）  一人当たり賃金（万円）
# 0  2010        1   北海道     年齢計       26.23             67.15       381.91
# 1  2010        1   北海道    〜19歳       15.29             14.41       197.89
# 2  2010        1   北海道  20〜24歳       18.04             30.16       246.64
# 3  2010        1   北海道  25〜29歳       20.93             48.06       299.22
# 4  2010        1   北海道  30〜34歳       24.08             57.10       346.06

# %%
df_temp2 = df_pref_ind[(df_pref_ind["年齢"] == "年齢計")]
df_temp2
# Out:
#        集計年  都道府県コード 都道府県名   年齢  所定内給与額（万円）  年間賞与その他特別給与額（万円）  一人当たり賃金（万円）
# 0     2010        1   北海道  年齢計       26.23             67.15       381.91
# 13    2010        2   青森県  年齢計       22.65             43.99       315.79
# 26    2010        3   岩手県  年齢計       23.68             49.26       333.42
# 39    2010        4   宮城県  年齢計       26.38             64.46       381.02
# 52    2010        5   秋田県  年齢計       22.94             46.83       322.11
# ...    ...      ...   ...  ...         ...               ...          ...
# 6045  2019       43   熊本県  年齢計       25.88             69.78       380.34
# 6058  2019       44   大分県  年齢計       26.03             72.51       384.87
# 6071  2019       45   宮崎県  年齢計       24.30             63.17       354.77
# 6084  2019       46  鹿児島県  年齢計       25.73             69.70       378.46
# 6097  2019       47   沖縄県  年齢計       25.13             53.86       355.42
#
# [470 rows x 7 columns]

# %%
df_temp2.groupby(['都道府県名'])[['所定内給与額（万円）', '年間賞与その他特別給与額（万円）', '一人当たり賃金（万円）']].mean()
# Out:
#        所定内給与額（万円）  年間賞与その他特別給与額（万円）  一人当たり賃金（万円）
# 都道府県名
# 三重県        29.328            87.231      439.167
# 京都府        30.365            86.794      451.174
# 佐賀県        24.401            60.980      353.792
# 兵庫県        29.761            87.199      444.331
# 北海道        26.443            66.039      383.355
# 千葉県        30.079            77.712      438.660
# 和歌山県       27.396            75.024      403.776
# 埼玉県        29.829            76.492      434.440
# 大分県        25.207            64.163      366.647
# 大阪府        32.171            93.642      479.694
# 奈良県        29.383            75.866      428.462
# 宮城県        27.767            74.589      407.793
# 宮崎県        23.587            58.657      341.701
# 富山県        27.301            74.557      402.169
# 山口県        26.849            77.720      399.908
# 山形県        24.118            55.883      345.299
# 山梨県        27.907            78.852      413.736
# 岐阜県        27.837            75.758      409.802
# 岡山県        27.538            76.898      407.354
# 岩手県        23.677            54.724      338.848
# 島根県        24.873            62.828      361.304
# 広島県        28.774            81.197      426.485
# 徳島県        26.684            77.614      397.822
# 愛媛県        25.798            67.799      377.375
# 愛知県        31.461           106.806      484.338
# 新潟県        26.080            64.462      377.422
# 東京都        37.379           119.277      567.825
# 栃木県        28.891            82.415      429.107
# 沖縄県        23.517            45.181      327.385
# 滋賀県        29.456            88.336      441.808
# 熊本県        25.409            64.605      369.513
# 石川県        27.314            74.671      402.439
# 神奈川県       33.249            98.789      497.777
# 福井県        27.088            72.414      397.470
# 福岡県        27.963            75.490      411.046
# 福島県        26.054            64.695      377.343
# 秋田県        23.737            53.911      338.755
# 群馬県        28.048            77.310      413.886
# 茨城県        29.654            88.940      444.788
# 長崎県        24.724            63.143      359.831
# 長野県        27.637            74.083      405.727
# 青森県        23.237            51.494      330.338
# 静岡県        28.717            83.732      428.336
# 香川県        27.282            74.170      401.554
# 高知県        25.278            60.496      363.832
# 鳥取県        24.736            59.114      355.946
# 鹿児島県       24.987            61.067      360.911

# %%
df_temp2.loc[df_temp2['一人当たり賃金（万円）'].idxmax()]
# Out:
# 集計年                   2015
# 都道府県コード                 13
# 都道府県名                  東京都
# 年齢                     年齢計
# 所定内給与額（万円）            38.3
# 年間賞与その他特別給与額（万円）    128.66
# 一人当たり賃金（万円）         588.26
# Name: 3211, dtype: object

# %%
df_pref_category.head()
# Out:
#     集計年  都道府県コード 都道府県名 産業大分類コード        産業大分類名      年齢  所定内給与額（万円）  \
# 0  2010        1   北海道        C  鉱業，採石業，砂利採取業     年齢計       28.85
# 1  2010        1   北海道        C  鉱業，採石業，砂利採取業    〜19歳       18.84
# 2  2010        1   北海道        C  鉱業，採石業，砂利採取業  20〜24歳       21.13
# 3  2010        1   北海道        C  鉱業，採石業，砂利採取業  25〜29歳       25.25
# 4  2010        1   北海道        C  鉱業，採石業，砂利採取業  30〜34歳       24.54
#
#    年間賞与その他特別給与額（万円）  一人当たり賃金（万円）
# 0             74.95       421.15
# 1             19.88       245.96
# 2             89.56       343.12
# 3             83.94       386.94
# 4             66.53       361.01

# %%
df_temp3 = df_pref_category[(df_pref_category["年齢"] == "年齢計")]

# %%
df_pref3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [164], in <cell line: 1>()
# ----> 1 df_pref3
#
# NameError: name 'df_pref3' is not defined

# %%
df_temp3
# Out:
#         集計年  都道府県コード 都道府県名 産業大分類コード             産業大分類名   年齢  所定内給与額（万円）  \
# 0      2010        1   北海道        C       鉱業，採石業，砂利採取業  年齢計       28.85
# 13     2010        1   北海道        D                建設業  年齢計       27.91
# 26     2010        1   北海道        E                製造業  年齢計       24.00
# 39     2010        1   北海道        F      電気・ガス・熱供給・水道業  年齢計       41.57
# 52     2010        1   北海道        G              情報通信業  年齢計       32.17
# ...     ...      ...   ...      ...                ...  ...         ...
# 97695  2019       47   沖縄県        N      生活関連サービス業，娯楽業  年齢計       21.69
# 97708  2019       47   沖縄県        O           教育，学習支援業  年齢計       33.53
# 97721  2019       47   沖縄県        P              医療，福祉  年齢計       27.51
# 97734  2019       47   沖縄県        Q           複合サービス事業  年齢計       24.40
# 97747  2019       47   沖縄県        R  サービス業（他に分類されないもの）  年齢計       21.80
#
#        年間賞与その他特別給与額（万円）  一人当たり賃金（万円）
# 0                 74.95       421.15
# 13                53.56       388.48
# 26                64.95       352.95
# 39               175.37       674.21
# 52                89.39       475.43
# ...                 ...          ...
# 97695             31.46       291.74
# 97708             76.97       479.33
# 97721             59.09       389.21
# 97734             69.98       362.78
# 97747             32.39       293.99
#
# [7509 rows x 9 columns]

# %%
df_temp3.groupby(['都道府県名', '産業大分類名'])[['所定内給与額（万円）', '年間賞与その他特別給与額（万円）', '一人当たり賃金（万円）']].mean()
# Out:
#                          所定内給与額（万円）  年間賞与その他特別給与額（万円）  一人当たり賃金（万円）
# 都道府県名 産業大分類名
# 三重県   サービス業（他に分類されないもの）      25.112            50.460      351.804
#       不動産業，物品賃貸業             26.517            61.695      379.899
#       医療，福祉                  27.775            75.603      408.903
#       卸売業，小売業                27.549            70.685      401.273
#       学術研究，専門・技術サービス業        31.571           102.327      481.179
# ...                             ...               ...          ...
# 鹿児島県  複合サービス事業               24.118            73.934      363.350
#       運輸業，郵便業                22.648            40.634      312.410
#       金融業，保険業                32.633           117.269      508.865
#       鉱業，採石業，砂利採取業           28.231           108.969      447.741
#       電気・ガス・熱供給・水道業          39.386           124.642      597.274
#
# [752 rows x 3 columns]

# %%
df_temp3_group = df_temp3.groupby(['都道府県名', '産業大分類名'])[['所定内給与額（万円）', '年間賞与その他特別給与額（万円）', '一人当たり賃金（万円）']].mean()

# %%
ls
# Out:
# TakaoPGothic.ttf  csv_data/         jp_wage.ipynb

# %%
df_temp3_group.loc['三重県': '京都府']
# Out:
#                          所定内給与額（万円）  年間賞与その他特別給与額（万円）  一人当たり賃金（万円）
# 都道府県名 産業大分類名
# 三重県   サービス業（他に分類されないもの）      25.112            50.460      351.804
#       不動産業，物品賃貸業             26.517            61.695      379.899
#       医療，福祉                  27.775            75.603      408.903
#       卸売業，小売業                27.549            70.685      401.273
#       学術研究，専門・技術サービス業        31.571           102.327      481.179
#       宿泊業，飲食サービス業            23.117            31.253      308.657
#       建設業                    32.007            69.838      453.922
#       情報通信業                  31.075            99.230      472.130
#       教育，学習支援業               35.327           116.295      540.219
#       生活関連サービス業，娯楽業          25.794            52.150      361.678
#       製造業                    30.540           103.944      470.424
#       複合サービス事業               28.450            99.053      440.453
#       運輸業，郵便業                26.873            53.954      376.430
#       金融業，保険業                33.771           137.115      542.367
#       鉱業，採石業，砂利採取業           29.568            55.754      410.570
#       電気・ガス・熱供給・水道業          39.863           147.188      625.544
# 京都府   サービス業（他に分類されないもの）      25.311            55.526      359.258
#       不動産業，物品賃貸業             29.196            77.672      428.024
#       医療，福祉                  29.136            79.356      428.988
#       卸売業，小売業                29.197            71.128      421.492
#       学術研究，専門・技術サービス業        38.678           122.315      586.451
#       宿泊業，飲食サービス業            24.802            34.488      332.112
#       建設業                    31.027            67.970      440.294
#       情報通信業                  34.177           111.368      521.492
#       教育，学習支援業               41.754           163.448      664.496
#       生活関連サービス業，娯楽業          26.026            43.545      355.857
#       製造業                    31.429           104.099      481.247
#       複合サービス事業               30.347            95.919      460.083
#       運輸業，郵便業                24.672            47.838      343.902
#       金融業，保険業                33.540           130.044      532.524
#       鉱業，採石業，砂利採取業           29.402            52.590      405.414
#       電気・ガス・熱供給・水道業          35.447           125.954      551.318

# %%
font_path = 'TakaoPGothic.ttf'
font_property = FontProperties(fname=font_path)

# %%
df_ts_mean = df_jp_ind[(df_jp_ind["年齢"] == "年齢計")]
df_ts_mean
# Out:
#       集計年   年齢  所定内給与額（万円）  年間賞与その他特別給与額（万円）  一人当たり賃金（万円）
# 0    2010  年齢計     29.6219           79.1174     434.5804
# 13   2011  年齢計     29.6784           82.3747     438.5151
# 26   2012  年齢計     29.7757           81.9302     439.2385
# 39   2013  年齢計     29.5735           80.1316     435.0136
# 52   2014  年齢計     29.9630           84.1634     443.7198
# 65   2015  年齢計     30.4022           89.2692     454.0960
# 78   2016  年齢計     30.3988           89.4192     454.2043
# 91   2017  年齢計     30.4291           90.5953     455.7445
# 104  2018  年齢計     30.6196           93.1651     460.6006
# 117  2019  年齢計     30.7692           95.0934     464.3237

# %%
df_ts_mean = df_ts_mean.set_index('集計年')
df_ts_mean
# Out:
#        年齢  所定内給与額（万円）  年間賞与その他特別給与額（万円）  一人当たり賃金（万円）
# 集計年
# 2010  年齢計     29.6219           79.1174     434.5804
# 2011  年齢計     29.6784           82.3747     438.5151
# 2012  年齢計     29.7757           81.9302     439.2385
# 2013  年齢計     29.5735           80.1316     435.0136
# 2014  年齢計     29.9630           84.1634     443.7198
# 2015  年齢計     30.4022           89.2692     454.0960
# 2016  年齢計     30.3988           89.4192     454.2043
# 2017  年齢計     30.4291           90.5953     455.7445
# 2018  年齢計     30.6196           93.1651     460.6006
# 2019  年齢計     30.7692           95.0934     464.3237

# %%
fig = plt.figure(figsize=(10,5))
ax = plt.axes()
ax.set_xlabel("年", fontproperties=font_property)
ax.set_ylabel("一人当たり賃金（万円）", fontproperties=font_property)
ax.plot(df_ts_mean['一人当たり賃金（万円）'])
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
ax = plt.axes()
ax.set_xlabel("年")
ax.set_ylabel("一人当たり賃金（万円）")
ax.plot(df_ts_mean['一人当たり賃金（万円）'])
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
ax = plt.axes()
ax.set_xlabel("年", fontproperties=font_property)
ax.set_ylabel("一人当たり賃金（万円）", fontproperties=font_property)
ax.plot(df_ts_mean['一人当たり賃金（万円）'])
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
ax = plt.axes()
ax.set_xlabel("年", fontproperties=font_property)
ax.set_ylabel("年間賞与その他特別給与額（万円）", fontproperties=font_property)
ax.plot(df_ts_mean['年間賞与その他特別給与額（万円）'])
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
ax = plt.axes()
ax.set_xlabel("年", fontproperties=font_property)
ax.set_ylabel("所定内給与額（万円）", fontproperties=font_property)
ax.plot(df_ts_mean['所定内給与額（万円）'])
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
ax = plt.axes()
ax.set_xlabel("年", fontproperties=font_property)
ax.set_ylabel("所定内給与額（万円）", fontproperties=font_property)
ax.set_ylim(10, 40)
ax.plot(df_ts_mean['所定内給与額（万円）'])
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
ax = plt.axes()
ax.set_xlabel("年", fontproperties=font_property)
ax.set_ylabel("所定内給与額（万円）", fontproperties=font_property)
ax.set_ylim(10, 40)
ax.plot(df_ts_mean['所定内給与額（万円）'])
plt.show()

# %%
print(df_pref_category.shape)
df_pref_category.head()
# Out:
# (94234, 9)
#     集計年  都道府県コード 都道府県名 産業大分類コード        産業大分類名      年齢  所定内給与額（万円）  \
# 0  2010        1   北海道        C  鉱業，採石業，砂利採取業     年齢計       28.85
# 1  2010        1   北海道        C  鉱業，採石業，砂利採取業    〜19歳       18.84
# 2  2010        1   北海道        C  鉱業，採石業，砂利採取業  20〜24歳       21.13
# 3  2010        1   北海道        C  鉱業，採石業，砂利採取業  25〜29歳       25.25
# 4  2010        1   北海道        C  鉱業，採石業，砂利採取業  30〜34歳       24.54
#
#    年間賞与その他特別給与額（万円）  一人当たり賃金（万円）
# 0             74.95       421.15
# 1             19.88       245.96
# 2             89.56       343.12
# 3             83.94       386.94
# 4             66.53       361.01

# %%
ls
# Out:
# TakaoPGothic.ttf  csv_data/         jp_wage.ipynb

# %%
age_list = df_pref_category['年齢'].unique()
print(age_list)
# Out:
# ['年齢計' '〜19歳' '20〜24歳' '25〜29歳' '30〜34歳' '35〜39歳' '40〜44歳' '45〜49歳'
#  '50〜54歳' '55〜59歳' '60〜64歳' '65〜69歳' '70歳〜']

# %%
wage_list = []

# %%
wage_list = []
for age in age_list:
    print(age)
    wage_temp = df_pref_category[df_pref_category['年齢'] == age]['一人当たり賃金（万円）'].values.tolist()
    wage_list.append(wage_temp)
# Out:
# 年齢計
# 〜19歳
# 20〜24歳
# 25〜29歳
# 30〜34歳
# 35〜39歳
# 40〜44歳
# 45〜49歳
# 50〜54歳
# 55〜59歳
# 60〜64歳
# 65〜69歳
# 70歳〜

# %%
len(wage_list)
# Out:
# 13

# %%
len(wage_list[0])
# Out:
# 7509

# %%
fig = plt.figure(figsize=(16,6))
ax = plt.axes()
ax.set_title('年齢階級ごとの一人当たり賃金', fontproperties=font_property)
ax.set_xticklabels(age_list, fontproperties=font_property)
ax.boxplot(wage_list)
plt.show()

# %%
fig = plt.figure(figsize=(16,6))
ax = plt.axes()
ax.set_title('年齢階級ごとの一人当たり賃金', fontproperties=font_property)
ax.set_xticklabels(age_list, fontproperties=font_property)
ax.boxplot(wage_list, showfliers=False)
plt.show()

# %%
wage_list = []
for age in age_list:
    print(age)
    wage_temp2 = df_pref_category[df_pref_category['年齢'] == age]['一人当たり賃金（万円）']
    wage_list.append(wage_temp2)
# Out:
# 年齢計
# 〜19歳
# 20〜24歳
# 25〜29歳
# 30〜34歳
# 35〜39歳
# 40〜44歳
# 45〜49歳
# 50〜54歳
# 55〜59歳
# 60〜64歳
# 65〜69歳
# 70歳〜

# %%
wage_temp2
# Out:
# 12       216.00
# 25       263.76
# 38       176.24
# 64       467.85
# 77       180.46
#           ...
# 97694    195.56
# 97707    140.19
# 97720    379.10
# 97733    444.24
# 97759    183.78
# Name: 一人当たり賃金（万円）, Length: 5819, dtype: float64

# %%
wage_list2 = []
for age in age_list:
    print(age)
    wage_temp2 = df_pref_category[df_pref_category['年齢'] == age]['一人当たり賃金（万円）']
    wage_list2.append(wage_temp2)
# Out:
# 年齢計
# 〜19歳
# 20〜24歳
# 25〜29歳
# 30〜34歳
# 35〜39歳
# 40〜44歳
# 45〜49歳
# 50〜54歳
# 55〜59歳
# 60〜64歳
# 65〜69歳
# 70歳〜

# %%
print(wage_temp2)
# Out:
# 12       216.00
# 25       263.76
# 38       176.24
# 64       467.85
# 77       180.46
#           ...
# 97694    195.56
# 97707    140.19
# 97720    379.10
# 97733    444.24
# 97759    183.78
# Name: 一人当たり賃金（万円）, Length: 5819, dtype: float64

# %%
fig = plt.figure(figsize=(16,6))
ax = plt.axes()
ax.set_title('年齢階級ごとの一人当たり賃金', fontproperties=font_property)
ax.set_xticklabels(age_list, fontproperties=font_property)
ax.boxplot(wage_list, showfliers=False)
plt.show()

# %%
ind_list = df_pref_category['産業大分類名'].unique()
print(ind_list)
# Out:
# ['鉱業，採石業，砂利採取業' '建設業' '製造業' '電気・ガス・熱供給・水道業' '情報通信業' '運輸業，郵便業' '卸売業，小売業'
#  '金融業，保険業' '不動産業，物品賃貸業' '学術研究，専門・技術サービス業' '宿泊業，飲食サービス業' '生活関連サービス業，娯楽業'
#  '教育，学習支援業' '医療，福祉' '複合サービス事業' 'サービス業（他に分類されないもの）']

# %%
wage_list = [] #空のリスト
for name in ind_list: #202で作成したユニークな値のリスト
    print(name) #ユニークな値を順次印刷する
    wage_temp = df_pref_category[df_pref_category['産業大分類名'] == name]['一人当たり賃金（万円）'].values.tolist()
    #df_pref_categoryのデータフレームから産業大分類名を取りnameへ置換？別の列として一人当たり賃金を取得？シリーズをリストへ変換？
    wage_list.append(wage_temp) #wage_listへwage_tempを追加していく？
# Out:
# 鉱業，採石業，砂利採取業
# 建設業
# 製造業
# 電気・ガス・熱供給・水道業
# 情報通信業
# 運輸業，郵便業
# 卸売業，小売業
# 金融業，保険業
# 不動産業，物品賃貸業
# 学術研究，専門・技術サービス業
# 宿泊業，飲食サービス業
# 生活関連サービス業，娯楽業
# 教育，学習支援業
# 医療，福祉
# 複合サービス事業
# サービス業（他に分類されないもの）

# %%
fig = plt.figure(figsize=(16,6)) #Figureオブジェクトを作成
ax = plt.axes()
ax.set_title('産業別の一人あたり賃金', fontproperties=font_property)
ax.set_xticklabels(ind_list, fontproperties=font_property, rotation=80) #ラベル名が長いので横軸ラベルを回転する80度rotation
ax.boxplot(wage_list)
plt.show()

# %%
fig = plt.figure(figsize=(16,6)) #Figureオブジェクトを作成
ax = plt.axes()
ax.set_title('産業別の一人あたり賃金', fontproperties=font_property)
ax.set_xticklabels(ind_list, fontproperties=font_property, rotation=80) #ラベル名が長いので横軸ラベルを回転する80度rotation
ax.boxplot(wage_list, showfliers=False)
plt.show()

# %%
print(wage_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [212], in <cell line: 5>()
#       3 ax.set_title('産業別の一人あたり賃金', fontproperties=font_property)
#       4 ax.set_xticklabels(ind_list, fontproperties=font_property, rotation=80) #ラベル名が長いので横軸ラベルを回転する80度rotation
# ----> 5 ax.lineplot(wage_list)
#       6 plt.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'lineplot'

# %%
index(wage_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [215], in <cell line: 1>()
# ----> 1 index(wage_list)
#
# NameError: name 'index' is not defined

# %%
len(wage_list)
# Out:
# 16

# %%
len(wage_temp)
# Out:
# 6106

# %%
print(len(wage_temp))
# Out:
# 6106

# %%
fig = plt.figure(figsize=(16,6)) #Figureオブジェクトを作成
ax = plt.axes()
ax.set_title('産業別の一人あたり賃金', fontproperties=font_property)
ax.set_xticklabels(ind_list, fontproperties=font_property, rotation=80) #ラベル名が長いので横軸ラベルを回転する80度rotation
ax.boxplot(wage_temp)3
plt.show()
